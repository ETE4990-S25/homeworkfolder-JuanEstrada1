# %% [markdown]
# # Homework #5 - MatPlot and NumPy
#
#
#
# #Part 1 Mat Plot Lib
#
# Using Matplotlib create the following graphs

# %%
# Inports Here

# %%
# Histogram
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
data = np.random.randn(1000)  # Creates 1000 random numbers from a normal distribution

# Create the histogram
plt.figure(figsize=(10, 6))  # Set figure size
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

# Add titles and labels
plt.title('Histogram Example')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Add a grid
plt.grid(True, alpha=0.3)

# Display the plot
plt.show()

# %%
# Line Plot
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)  # Creates 100 evenly spaced points from 0 to 10
y = np.sin(x)  # Calculates sine values for each x point

# Create the line plot
plt.figure(figsize=(10, 6))  # Set figure size
plt.plot(x, y, 'b-', label='Sine Wave')  # 'b-' means blue line

# Add titles and labels
plt.title('Line Plot Example - Sine Wave')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add a grid
plt.grid(True, alpha=0.3)

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
# Scatter Plot
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.random.normal(0, 1, 50)  # 50 random points from normal distribution
y = np.random.normal(0, 1, 50)  # 50 random points from normal distribution
sizes = np.random.uniform(20, 200, 50)  # Random sizes for points
colors = np.random.uniform(0, 100, 50)  # Random colors for points

# Create the scatter plot
plt.figure(figsize=(10, 6))  # Set figure size
plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')

# Add titles and labels
plt.title('Scatter Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add a colorbar
plt.colorbar(label='Color Scale')

# Add a grid
plt.grid(True, alpha=0.3)

# Display the plot
plt.show()

# %%
# Pie Plot
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = [25, 35, 20, 20]
colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99']
explode = (0.1, 0, 0, 0)  # Explode the first slice

# Create the pie plot
plt.figure(figsize=(8, 8))  # Set figure size
plt.pie(values, 
        labels=categories,
        colors=colors,
        explode=explode,
        autopct='%1.1f%%',  # Show percentages
        shadow=True,
        startangle=90)  # Start angle at 90 degrees

# Add a title
plt.title('Pie Chart Example')

# Equal aspect ratio ensures pie is drawn as a circle
plt.axis('equal')

# Display the plot
plt.show()

# %%
# Area Plot
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 50)  # 50 points from 0 to 10
y1 = np.sin(x)  # First dataset
y2 = np.cos(x)  # Second dataset

# Create the area plot
plt.figure(figsize=(10, 6))  # Set figure size
plt.fill_between(x, y1, alpha=0.4, label='Sine', color='skyblue')
plt.fill_between(x, y2, alpha=0.4, label='Cosine', color='lightcoral')

# Add titles and labels
plt.title('Area Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add a grid
plt.grid(True, alpha=0.3)

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
# 3d Plot - Bar Plot
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Create figure and 3D axes
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Generate sample data
x = np.array([1, 2, 3, 4, 5])  # X coordinates
y = np.array([1, 2, 3, 4, 5])  # Y coordinates
z = np.zeros(5)  # Bottom of bars (z=0)

# Heights of bars
dx = dy = np.ones(5) * 0.8  # Width and depth of bars
dz = np.array([4, 7, 2, 5, 3])  # Heights of bars

# Create the 3D bar plot
ax.bar3d(x, y, z, dx, dy, dz, color=['#FF9999', '#66B2FF', '#99FF99', '#FFCC99', '#D8BFD8'])

# Customize the plot
ax.set_title('3D Bar Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Height')

# Set viewing angle (elevation, azimuth)
ax.view_init(elev=20, azim=45)

# Display the plot
plt.show()

# %% [markdown]
# # Part 2 - Num Py
# Like a dictionary, we can create a structured array in Numpy
#
# ```python
# data = np.array([
#     ("Billy", 32, 6),
#     ("Bob", 15, 20),
#     ("Jo", 80, 100),
#     ("Goku", 38, 9001),],
#     dtype=[("name", str, 10),
#            ("age", int),
#            ("power", int)])
# ```
#
# Using the following file https://www.kaggle.com/datasets/gregorut/videogamesales
#
# Create and sort the data by Name, Year, and NA_Sales
#
# Do not use pandas
#
# You can use this to help start you on your way
# https://stackoverflow.com/questions/57785790/construct-structured-numpy-array-from-a-file

# %%
import numpy as np

# Define the data type for the structured array
dtype = [('Name', 'U50'),  # Unicode string with max length 50
         ('Year', 'i4'),   # 4-byte integer for year
         ('NA_Sales', 'f4')]  # 4-byte float for NA sales

# Function to read and process the CSV file
def load_vg_data(filename):
    # Read the CSV file
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    # Skip header and count valid lines
    data_lines = lines[1:]  # Skip header row
    n_rows = len(data_lines)
    
    # Initialize empty array
    data = np.zeros(n_rows, dtype=dtype)
    
    # Fill the array
    for i, line in enumerate(data_lines):
        fields = line.strip().split(',')
        try:
            # Extract relevant fields:
            # Name (index 1), Year (index 3), NA_Sales (index 6)
            name = fields[1]
            year = float(fields[3]) if fields[3] else 0  # Handle missing years
            na_sales = float(fields[6])
            
            data[i] = (name, int(year), na_sales)
        except (ValueError, IndexError):
            # Handle any parsing errors (e.g., missing data)
            data[i] = (name if name else "Unknown", 0, 0.0)
    
    return data

# Load the data (replace 'vgsales.csv' with your actual file path)
filename = 'vgsales.csv'  # Update this to your local file path
vg_data = load_vg_data(filename)

# Sort the data by Name, then Year, then NA_Sales
sorted_data = np.sort(vg_data, order=['Name', 'Year', 'NA_Sales'])

# Print the first few rows to verify
print("First 5 rows of sorted data:")
for row in sorted_data[:5]:
    print(f"Name: {row['Name']:<30} Year: {row['Year']:>4} NA_Sales: {row['NA_Sales']:>6.2f}")

# Print the last few rows
print("\nLast 5 rows of sorted data:")
for row in sorted_data[-5:]:
    print(f"Name: {row['Name']:<30} Year: {row['Year']:>4} NA_Sales: {row['NA_Sales']:>6.2f}")
# Out:
# Please provide the correct path to vgsales.csv
